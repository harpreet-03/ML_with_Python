# %% [markdown]
# **Importing the Libraries**

# %%
import numpy as np # type: ignore
import pandas as pd # type: ignore

# %%
import seaborn as sns # type: ignore
import matplotlib.pyplot as plt # type: ignore
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **Loading the dataset**

# %%
df = sns.load_dataset("mpg")
org_df = sns.load_dataset("mpg")

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
df.drop(['name'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin
# 0          70    usa
# 1          70    usa
# 2          70    usa
# 3          70    usa
# 4          70    usa

# %%
df.shape
# Out:
# (398, 8)

# %% [markdown]
# **Summary of the dataset**

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %% [markdown]
# **Data pre-processing**

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
df[df.isnull().any(axis = 1)] 

'''

# If there is atleast one empty value in the column, it will give us output.
# so this code will print all missing lines in horsepower (total 6 null values)

Note:

axis=0: Operates along columns (default).
axis=1: Operates along rows.

'''
# Out:
# '\n\n# If there is atleast one empty value in the column, it will give us output.\n# so this code will print all missing lines in horsepower (total 6 null values)\n\nNote:\n\naxis=0: Operates along columns (default).\naxis=1: Operates along rows.\n\n'

# %%
# I want to drop all Blank lines (Dropping)
# Another method to handle missing values is Imputation (Mean, median, mode)

# %%
# Drop
df.dropna(inplace=True)
org_df.dropna(inplace=True)

# %%
df.isnull().sum().any()
# It'll print True if there exist atleast a single null/ blank value otherwise it'll return False
# Out:
# False

# %%
df.shape
# Out:
# (392, 8)

# %% [markdown]
# **UNIVARIATE ANALYSIS**

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin
# 0          70    usa
# 1          70    usa
# 2          70    usa
# 3          70    usa
# 4          70    usa

# %%
df.cylinders.unique()
# Out:
# array([8, 4, 6, 3, 5], dtype=int64)

# %%
df.cylinders.value_counts()
# Out:
# cylinders
# 4    199
# 8    103
# 6     83
# 3      4
# 5      3
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="cylinders", data=df, palette="cubehelix")
plt.show()

# %%
df['model_year'] = (1900 + df['model_year'])

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin
# 0        1970    usa
# 1        1970    usa
# 2        1970    usa
# 3        1970    usa
# 4        1970    usa

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="model_year", data=df, palette="cubehelix")
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="origin", data=df, palette="cubehelix")
plt.show()

# %%
sns.distplot(df['horsepower'])
plt.show()

# %% [markdown]
# **BIVARIATE ANALYSIS**

# %%
plt.figure(figsize = (15,8))
sns.boxplot(x = 'cylinders', y = 'mpg', data = df, palette = 'cubehelix')
# Out:
# <Axes: xlabel='cylinders', ylabel='mpg'>

# %%
plt.figure(figsize = (15,8))
sns.boxplot(x = 'model_year', y = 'mpg', data = df, palette = 'cubehelix')
# Out:
# <Axes: xlabel='model_year', ylabel='mpg'>

# %% [markdown]
# **MULTIVARIATE ANALYSIS**

# %%
sns.lmplot(x='horsepower', y='mpg', hue = 'origin', data=df, palette='rainbow')

# %%
sns.lmplot(x='acceleration', y='mpg', data=df, palette='rainbow', hue='origin')
# mpg increased with acceleration in this plot graph

# %%
sns.lmplot(x='weight', data=df, y='mpg', palette='rainbow', hue='origin')
# as weight increase, mpg is decreasing

# %%
sns.lmplot(x='displacement', data=df, y='mpg', palette='rainbow', hue='origin')
# mpg value decrease as engine volume increases

# %% [markdown]
# **HeatMap of Correlation matrix**

# %%
print(df.dtypes)
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# dtype: object

# %%
df.drop(['origin'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  model_year
# 0  18.0          8         307.0       130.0    3504          12.0        1970
# 1  15.0          8         350.0       165.0    3693          11.5        1970
# 2  18.0          8         318.0       150.0    3436          11.0        1970
# 3  16.0          8         304.0       150.0    3433          12.0        1970
# 4  17.0          8         302.0       140.0    3449          10.5        1970

# %%
plt.figure(figsize=(15,9))
sns.heatmap(df.corr(), annot=True, linewidths=0.5, cmap = 'Spectral')
# Out:
# <Axes: >

# %%
org_df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
org_df.drop(['displacement'], axis = 1, inplace = True)

# %%
org_df.drop(['acceleration'], axis = 1, inplace = True)

# %%
org_df.drop(['name'], axis = 1, inplace = True)

# %%
org_df['model_year'] = (1900 + org_df['model_year'])

# %%
org_df.head()
# Out:
#     mpg  cylinders  horsepower  weight  model_year origin
# 0  18.0          8       130.0    3504        1970    usa
# 1  15.0          8       165.0    3693        1970    usa
# 2  18.0          8       150.0    3436        1970    usa
# 3  16.0          8       150.0    3433        1970    usa
# 4  17.0          8       140.0    3449        1970    usa

# %%
from datetime import datetime

# %%
today = datetime.today()

# %%
today
# Out:
# datetime.datetime(2024, 8, 26, 13, 26, 41, 295975)

# %%
this_year = today.year
this_year
# Out:
# 2024

# %%
org_df["age"] = this_year - org_df.model_year

# %%
org_df.drop(["model_year"], axis=1, inplace=True)

# %%
org_df.head()
# Out:
#     mpg  cylinders  horsepower  weight origin  age
# 0  18.0          8       130.0    3504    usa   54
# 1  15.0          8       165.0    3693    usa   54
# 2  18.0          8       150.0    3436    usa   54
# 3  16.0          8       150.0    3433    usa   54
# 4  17.0          8       140.0    3449    usa   54

# %%
org_df.origin.unique()
# Out:
# array(['usa', 'japan', 'europe'], dtype=object)

# %%
org_df = pd.get_dummies(org_df, drop_first=True)

# %%
org_df.head()
# Out:
#     mpg  cylinders  horsepower  weight  age  origin_japan  origin_usa
# 0  18.0          8       130.0    3504   54         False        True
# 1  15.0          8       165.0    3693   54         False        True
# 2  18.0          8       150.0    3436   54         False        True
# 3  16.0          8       150.0    3433   54         False        True
# 4  17.0          8       140.0    3449   54         False        True

# %% [markdown]
# **Modelling**

# %%
X=org_df.drop(['mpg'], axis = 1)
y=org_df['mpg']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train
# Out:
#      cylinders  horsepower  weight  age  origin_japan  origin_usa
# 183          4        81.0    2220   48         False       False
# 119          4        91.0    2582   51         False       False
# 352          4        65.0    2380   43         False        True
# 3            8       150.0    3433   54         False        True
# 251          8       139.0    3570   46         False        True
# ..         ...         ...     ...  ...           ...         ...
# 344          4        64.0    1875   43         False        True
# 165          8       110.0    3221   49         False        True
# 28           8       193.0    4732   54         False        True
# 319          4        75.0    2542   44          True       False
# 299          4        71.0    3190   45         False       False
#
# [313 rows x 6 columns]

# %%
X_train.isnull().sum().any()
# Out:
# False

# %%
y_train
# Out:
# 183    25.0
# 119    20.0
# 352    29.9
# 3      16.0
# 251    20.2
#        ...
# 344    39.0
# 165    20.0
# 28      9.0
# 319    31.3
# 299    27.2
# Name: mpg, Length: 313, dtype: float64

# %%
y_train.isnull().sum().any()
# Out:
# False

# %%
from sklearn.linear_model import LinearRegression

# %%
lm_model = LinearRegression()

# %%
lm_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lm_model.intercept_
# Out:
# 76.10390862267221

# %%
coef_param = pd.DataFrame(lm_model.coef_, index=X.columns, columns=['Coefficient'])
coef_param
# Out:
#               Coefficient
# cylinders        0.233365
# horsepower      -0.011463
# weight          -0.005748
# age             -0.719200
# origin_japan     0.543084
# origin_usa      -1.891490

# %%
y_pred = lm_model.predict(X_test)

# %%
my_dict = {"Actual" : y_test,
           "Pred" : y_pred}

compare = pd.DataFrame(my_dict)

# %%
compare.sample(10)
# Out:
#      Actual       Pred
# 258    20.6  21.898448
# 120    19.0  22.589810
# 302    34.5  29.621840
# 250    19.4  19.923525
# 7      14.0   9.993756
# 254    20.2  24.513019
# 18     27.0  25.492236
# 63     14.0  11.471092
# 96     13.0  15.432015
# 255    25.1  25.420096

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
def evaluation_metrics(actual, pred):
    mse = mean_squared_error(actual, pred)
    mae = mean_absolute_error(actual, pred)
    rmse = np.sqrt(mean_squared_error(actual, pred))
    r2 = r2_score(actual, pred)
    return print("r2_score -> ", r2, "\n", "MAE -> ", mae, "\n", "MSE -> ", mse, "RMSE -> ", rmse)

# %%
evaluation_metrics(y_test, y_pred)
# Out:
# r2_score ->  0.8325621240914836
#  MAE ->  2.7473251797898204
#  MSE ->  11.593062632663505 RMSE ->  3.404858680277862

# %% [markdown]
# **K - Fold Cross Validation**

# %%
from sklearn.model_selection import cross_val_score

# %%
accuracies = cross_val_score(estimator=lm_model, X = X_train, y=y_train, cv = 10)

# %%
accuracies
# Out:
# array([0.72706907, 0.75799343, 0.78964962, 0.82812255, 0.77483513,
#        0.9055664 , 0.82014788, 0.81758155, 0.78296871, 0.7646098 ])

# %%
accuracies.mean()
# Out:
# 0.7968544122331607

# %%
accuracies = cross_val_score(estimator=lm_model, X = X_train, y=y_train, cv = 10)
